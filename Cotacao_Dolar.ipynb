# %% [markdown]
# <a href="https://colab.research.google.com/github/KauePetrica/Consumindo-APIs/blob/Apis/Cotacao_Dolar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
import json

# %%
cotacoes = requests.get("https://economia.awesomeapi.com.br/json/last/USD-BRL,EUR-BRL?token=MY_TOKEN")
cotacoes = cotacoes.json()
cotacao_dolar = cotacoes
#print(cotacoes)
print(cotacao_dolar)
# Out:
# {'USDBRL': {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '5.2749', 'low': '5.18205', 'varBid': '0.0687', 'pctChange': '1.323041', 'bid': '5.2613', 'ask': '5.2643', 'timestamp': '1773884452', 'create_date': '2026-03-18 22:40:52'}, 'EURBRL': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '6.03865', 'low': '5.97015', 'varBid': '0.050563', 'pctChange': '0.84491', 'bid': '6.035', 'ask': '6.04961', 'timestamp': '1773884443', 'create_date': '2026-03-18 22:40:43'}}
